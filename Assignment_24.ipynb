# %% [markdown]
# Use the Superstore_USA data and do the following
# - Create a Line chart in terms of Sales.
# - Create a Parameter in such a way that it can be used as a growth rate
# caluclator in terms of Percentage.
# - Growth Rate should be 5% with each increament.

# %% [markdown]
# 1.Create a Line chart in terms of Sales.

# %% [markdown]
# ![Assign.png](attachment:Assign.png)

# %% [markdown]
# Create a Parameter in such a way that it can be used as a growth rate caluclator in terms of Percentage.
# Growth Rate should be 5% with each increament.

# %% [markdown]
# ![ssignment_24.jpg](attachment:ssignment_24.jpg)
