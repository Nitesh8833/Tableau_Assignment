# %% [markdown]
# Find the inventory by:-
# • Category
# • Sub Category
# • Product
# • Location
# - Create a Dashboard
# - Create a story showing the visuals from Location, Product & Category

# %% [markdown]
# ![assignment_6.jpg](attachment:assignment_6.jpg)
