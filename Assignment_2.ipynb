# %% [markdown]
# Use – Superstore_Canada.xls and format your numbers exactly like
# shown in screenshot below

# %% [markdown]
# ![Sheet1.jpg](attachment:Sheet1.jpg)

# %% [markdown]
# Use – Superstore_Canada.xls and format your numbers exactly like
# shown in screenshot below

# %% [markdown]
# ![Sheet2.jpg](attachment:Sheet2.jpg)

# %% [markdown]
# What is the total sales of the store?

# %% [markdown]
# ![sheet3.jpg](attachment:sheet3.jpg)

# %% [markdown]
# What is the total sales of product category = “Furniture”?

# %% [markdown]
# ![sheet4.jpg](attachment:sheet4.jpg)

# %% [markdown]
# What is the total sales of product category = “Furniture” sold to Customer
# Segment = “Corporate”?

# %% [markdown]
# ![sheet5.jpg](attachment:sheet5.jpg)

# %% [markdown]
# Set the default number format of Discount to percentage with 2 decimal
# places.

# %% [markdown]
# ![sheet6.jpg](attachment:sheet6.jpg)

# %% [markdown]
# Find average discount on each order priority. Which order priority has
# highest average discount?

# %% [markdown]
# ![sheet7.jpg](attachment:sheet7.jpg)
